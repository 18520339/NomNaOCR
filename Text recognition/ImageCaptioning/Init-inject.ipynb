# %%
# https://arxiv.org/pdf/1703.09137.pdf
import sys
import tensorflow as tf
sys.path.append('..')
tf.get_logger().setLevel('ERROR')
APPROACH_NAME = 'Init-inject'

# %% [markdown]
# # Check GPU working

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)
# !nvcc -V
# Out:
# Found GPU at: /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:15:10_Pacific_Standard_Time_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0

# %% [markdown]
# # Data input pipeline

# %%
DATASET_DIR = r'../../Datasets/Patches'
ALL_TRANSCRIPTS_PATH = f'{DATASET_DIR}/All.txt'
VALID_TRANSCRIPTS_PATH = f'{DATASET_DIR}/Validate.txt'
FONT_PATH = r'../../NomNaTong-Regular.ttf'

# %% [markdown]
# ## Load and remove records with rare characters

# %%
from loader import DataImporter
dataset = DataImporter(DATASET_DIR, ALL_TRANSCRIPTS_PATH, min_length=1)
print(dataset)
# Out:
# Samples count (not include Latin letters, numbers, punctuations):
# - Number of images found: 37836
# - Number of labels found: 37836
# - Number of unique characters: 7479
# - Characters present: {'之': 7523, '以': 4796, '人': 3550, '月': 3446, '十': 3252, '不': 3145, '年': 3012, '帝': 2689, '有': 2541, '二': 2492, '其': 2449, '大': 2312, '日': 2260, '為': 2228, '等': 2082, '爲': 2018, '而': 1973, '國': 1946, '一': 1931, '軍': 1880, '王': 1872, '太': 1871, '公': 1830, '天': 1829, '子': 1792, '三': 1784, '官': 1783, '兵': 1778, '明': 1721, '曰': 1680, '於': 1629, '至': 1625, '使': 1597, '時': 1562, '者': 1561, '阮': 1550, '事': 1521, '臣': 1519, '也': 1498, '黎': 1409, '及': 1384, '文': 1374, '皇': 1359, '上': 1358, '如': 1352, '是': 1299, '行': 1258, '安': 1250, '五': 1240, '士': 1240, '中': 1217, '元': 1207, '四': 1199, '命': 1166, '下': 1165, '自': 1161, '民': 1120, '所': 1113, '宗': 1095, '書': 1047, '州': 1044, '六': 1029, '得': 1028, '道': 1015, '武': 1008, '于': 999, '生': 988, '都': 957, '吏': 946, '城': 939, '正': 922, '将': 907, '知': 899, '各': 889, '令': 884, '入': 881, '進': 880, '㐌': 871, '山': 871, '無': 869, '郡': 857, '史': 854, '後': 845, '諸': 845, '春': 842, '朝': 834, '名': 831, '部': 827, '内': 826, '出': 821, '陳': 814, '八': 792, '南': 788, '七': 784, '外': 780, '平': 773, '同': 768, '乃': 766, '府': 752, '遣': 736, '家': 732, '莫': 727, '在': 719, '師': 707, '德': 693, '鄭': 688, '司': 687, '定': 687, '則': 684, '朱': 683, '本': 679, '故': 679, '御': 677, '又': 671, '可': 671, '先': 668, '百': 667, '身': 664, '未': 653, '九': 651, '制': 651, '方': 650, '東': 643, '前': 642, '禮': 640, '浪': 638, '從': 630, '守': 629, '分': 628, '賊': 628, '立': 625, '娘': 622, '長': 620, '政': 616, '來': 615, '初': 612, '今': 609, '宋': 605, '江': 601, '世': 596, '固': 593, '門': 588, '見': 588, '此': 583, '縣': 582, '與': 581, '功': 579, '侯': 576, '情': 574, '相': 572, '用': 571, '言': 570, '詔': 569, '皆': 569, '清': 567, '興': 562, '\U000f047c': 561, '賜': 559, '復': 554, '奏': 551, '𢚸': 548, '侍': 547, '京': 546, '地': 542, '水': 542, '秋': 542, '拱': 540, '郎': 539, '心': 534, '位': 533, '左': 532, '群': 531, '罪': 530, '仁': 527, '尼': 525, '死': 522, '督': 515, '海': 515, '西': 515, '然': 511, '金': 510, '\U000f070b': 505, '殿': 503, '處': 501, '光': 500, '餘': 499, '領': 498, '主': 498, '我': 496, '衛': 495, '聖': 490, '𦋦': 488, '萬': 485, '封': 485, '還': 484, '多': 481, '路': 480, '奉': 467, '成': 465, '女': 465, '𠳒': 463, '后': 461, '化': 460, '保': 460, '親': 459, '花': 459, '𠬠': 457, '買': 450, '即': 447, '作': 447, '占': 447, '治': 447, '冬': 445, '𠊛': 444, '北': 440, '何': 439, '將': 437, '吳': 433, '林': 432, '節': 432, '義': 431, '夏': 428, '監': 427, '漢': 425, '差': 423, '馬': 423, '亦': 413, '卒': 410, '當': 408, '君': 408, '夫': 406, '重': 406, '神': 405, '矣': 404, '試': 401, '仍': 399, '右': 398, '宫': 396, '順': 396, '營': 395, '鎮': 393, '氏': 392, '埃': 391, '丁': 389, '李': 389, '居': 388, '強': 388, '院': 387, '殺': 387, '麻': 385, '少': 384, '常': 381, '回': 380, '會': 379, '法': 378, '畧': 375, '能': 372, '已': 372, '范': 371, '聞': 363, '廷': 360, '職': 358, '並': 357, '廣': 356, '陽': 356, '改': 356, '取': 354, '龍': 352, '刑': 350, '芇': 348, '通': 348, '承': 348, '非': 345, '經': 344, '黄': 343, '祖': 342, '號': 342, '欲': 340, '或': 336, '尚': 335, '土': 335, '社': 334, '科': 334, '宜': 334, '稱': 334, '連': 333, '伯': 331, '若': 331, '小': 330, '宣': 329, '永': 328, '登': 327, '福': 325, '牢': 324, '忠': 324, '副': 323, '欺': 323, '因': 322, '杜': 320, '率': 319, '降': 318, '船': 318, '許': 317, '眾': 317, '旨': 316, '問': 316, '別': 316, '意': 315, '頭': 315, '才': 315, '參': 313, '田': 313, '服': 312, '交': 312, '風': 311, '勑': 308, '父': 307, '察': 307, '遂': 304, '甲': 303, '威': 303, '𠓨': 302, '開': 302, '尉': 301, '學': 300, '嘉': 299, '應': 299, '象': 298, '憲': 297, '攻': 297, '惟': 295, '和': 295, '𡗶': 293, '謂': 293, '過': 293, '華': 293, '除': 292, '原': 292, '典': 291, '信': 290, '第': 290, '必': 290, '克': 289, '諭': 286, '直': 285, '起': 283, '越': 283, '實': 282, '置': 282, '兼': 282, '千': 282, '物': 281, '户': 281, '統': 279, '特': 278, '調': 278, '爵': 277, '敬': 277, '數': 277, '茹': 273, '爫': 272, '乎': 272, '傷': 271, '受': 271, '寺': 270, '終': 270, '擊': 269, '間': 268, '古': 268, '真': 268, '任': 267, '送': 266, '論': 265, '總': 265, '姓': 265, '度': 264, '征': 262, '力': 262, '浽': 259, '塘': 259, '并': 258, '䏻': 258, '凣': 258, '戰': 257, '払': 256, '食': 256, '失': 256, '禁': 255, '饒': 254, '求': ...

# %% [markdown]
# ## Data constants and input pipeline

# %%
HEIGHT, WIDTH = 432, 48
PADDING_CHAR = '[PAD]' 
START_CHAR = '[START]'
END_CHAR = '[END]'

# %%
from loader import DataHandler
data_handler = DataHandler(
    dataset, 
    img_size = (HEIGHT, WIDTH), 
    padding_char = PADDING_CHAR,
    start_char = START_CHAR,
    end_char = END_CHAR
)

# %%
NUM_VALIDATE = DataImporter(DATASET_DIR, VALID_TRANSCRIPTS_PATH, min_length=1).size
MAX_LENGTH = data_handler.max_length
START_TOKEN = data_handler.start_token
END_TOKEN = data_handler.end_token
VOCAB_SIZE = data_handler.char2num.vocab_size()
BATCH_SIZE = 32

# %% [markdown]
# ## Visualize the data

# %%
from visualizer import visualize_images_labels
visualize_images_labels(
    dataset.img_paths, 
    dataset.labels, 
    figsize = (15, 15),
    subplot_size = (2, 8),
    font_path = FONT_PATH
)

# %% [markdown]
# # Define model components

# %%
from tensorflow.keras.layers import Input, Embedding, Dense, GRU, Flatten
from layers import custom_cnn
EMBEDDING_DIM = 512
UNITS = 512

# %% [markdown]
# ## The CNN block

# %%
def FeaturesExtractor(imagenet_model=None, imagenet_output_layer=None, name='FeaturesExtractor'):
    # CNN block
    if imagenet_model: # Use Imagenet model as CNN layers
        image_input = imagenet_model.input
        imagenet_model.layers[0]._name = 'image'
        x = imagenet_model.get_layer(imagenet_output_layer).output
    else: 
        image_input = Input(shape=(HEIGHT, WIDTH, 3), dtype='float32', name='image')
        conv_blocks_config = {
            'block1': {'num_conv': 1, 'filters':  64, 'pool_size': (2, 2)}, 
            'block2': {'num_conv': 1, 'filters': 128, 'pool_size': (2, 2)}, 
            'block3': {'num_conv': 2, 'filters': 256, 'pool_size': (2, 2)}, 
            'block4': {'num_conv': 2, 'filters': 512, 'pool_size': (2, 2)}, 

            # Last Conv blocks with 2x2 kernel but without no padding and pooling layer
            'block5': {'num_conv': 2, 'filters': 512, 'pool_size': None}, 
        }
        x = custom_cnn(conv_blocks_config, image_input)
        
    # Reshape accordingly before adding output to RNN
    cnn_output = Dense(UNITS, name='cnn_output')(Flatten()(x))
    return tf.keras.Model(inputs=image_input, outputs=cnn_output, name=name)

# %% [markdown]
# ## The RNN block

# %%
def TextProcessor(features_shape, name='TextProcessor'):
    partial_seq_input = Input(shape=(MAX_LENGTH - 1,), dtype='int64', name='partial_caption')
    features_input = Input(shape=features_shape, name='image_features')
    rnn_output = GRU(UNITS, name='rnn_output')(
        Embedding(VOCAB_SIZE, EMBEDDING_DIM)(partial_seq_input), 
        initial_state = features_input
    )
    y_pred = Dense(VOCAB_SIZE, name='prediction')(rnn_output)
    return tf.keras.Model(inputs=[partial_seq_input, features_input], outputs=y_pred, name=name)

# %% [markdown]
# # Build the model

# %%
from models import get_imagenet_model, EarlyBindingCaptioner
imagenet_model, imagenet_output_layer = None, None
# # Pick a model from https://keras.io/api/applications
# imagenet_model = get_imagenet_model('VGG16', (HEIGHT, WIDTH, 3))
# imagenet_output_layer = 'block5_pool'
# imagenet_model.summary(line_length=100)

# %%
cnn_block = FeaturesExtractor(imagenet_model, imagenet_output_layer)
rnn_block = TextProcessor(cnn_block.output.shape[1:])
model = EarlyBindingCaptioner(cnn_block, rnn_block, data_handler)

# %%
cnn_block.summary(line_length=100)
print()
rnn_block.summary(line_length=100)
# Out:
# Model: "FeaturesExtractor"
# ____________________________________________________________________________________________________
#  Layer (type)                                Output Shape                            Param #
# ====================================================================================================
#  image (InputLayer)                          [(None, 432, 48, 3)]                    0
#
#  block1_conv1 (Conv2D)                       (None, 432, 48, 64)                     1792
#
#  block1_bn1 (BatchNormalization)             (None, 432, 48, 64)                     256
#
#  block1_relu1 (Activation)                   (None, 432, 48, 64)                     0
#
#  block1_pool (MaxPooling2D)                  (None, 216, 24, 64)                     0
#
#  block2_conv1 (Conv2D)                       (None, 216, 24, 128)                    73856
#
#  block2_bn1 (BatchNormalization)             (None, 216, 24, 128)                    512
#
#  block2_relu1 (Activation)                   (None, 216, 24, 128)                    0
#
#  block2_pool (MaxPooling2D)                  (None, 108, 12, 128)                    0
#
#  block3_conv1 (Conv2D)                       (None, 108, 12, 256)                    295168
#
#  block3_bn1 (BatchNormalization)             (None, 108, 12, 256)                    1024
#
#  block3_relu1 (Activation)                   (None, 108, 12, 256)                    0
#
#  block3_conv2 (Conv2D)                       (None, 108, 12, 256)                    590080
#
#  block3_bn2 (BatchNormalization)             (None, 108, 12, 256)                    1024
#
#  block3_relu2 (Activation)                   (None, 108, 12, 256)                    0
#
#  block3_pool (MaxPooling2D)                  (None, 54, 6, 256)                      0
#
#  block4_conv1 (Conv2D)                       (None, 54, 6, 512)                      1180160
#
#  block4_bn1 (BatchNormalization)             (None, 54, 6, 512)                      2048
#
#  block4_relu1 (Activation)                   (None, 54, 6, 512)                      0
#
#  block4_conv2 (Conv2D)                       (None, 54, 6, 512)                      2359808
#
#  block4_bn2 (BatchNormalization)             (None, 54, 6, 512)                      2048
#
#  block4_relu2 (Activation)                   (None, 54, 6, 512)                      0
#
#  block4_pool (MaxPooling2D)                  (None, 27, 3, 512)                      0
#
#  block5_conv1 (Conv2D)                       (None, 26, 2, 512)                      1049088
#
#  block5_bn1 (BatchNormalization)             (None, 26, 2, 512)                      2048
#
#  block5_relu1 (Activation)                   (None, 26, 2, 512)                      0
#
#  block5_conv2 (Conv2D)                       (None, 25, 1, 512)                      1049088
#
#  block5_bn2 (BatchNormalization)             (None, 25, 1, 512)                      2048
#
#  block5_relu2 (Activation)                   (None, 25, 1, 512)                      0
#
#  flatten (Flatten)                           (None, 12800)                           0
#
#  cnn_output (Dense)                          (None, 512)                             6554112
#
# ====================================================================================================
# Total params: 13,164,160
# Trainable params: 13,158,656
# Non-trainable params: 5,504
# ____________________________________________________________________________________________________
#
# Model: "TextProcessor"
# ____________________________________________________________________________________________________
#  Layer (type)                    Output Shape          Param #     Connected to
# ====================================================================================================
#  partial_caption (InputLayer)    [(None, 25)]          0           []
#
#  embedding (Embedding)           (None, 25, 512)       3831296     ['partial_caption[0][0]']
#
#  image_features (InputLayer)     [(None, 512)]         0           []
#
#  rnn_output (GRU)                (None, 512)           1575936     ['embedding[0][0]',
#                                                                     'image_features[0][0]']
#
#  prediction (Dense)              (None, 7483)          3838779     ['rnn_output[0][0]']
#
# ====================================================================================================
# Total params: 9,246,011
# Trainable params: 9,246,011
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
train_idxs = list(range(dataset.size - NUM_VALIDATE))
valid_idxs = list(range(train_idxs[-1] + 1, dataset.size))
print('Number of training samples:', len(train_idxs))
print('Number of validate samples:', len(valid_idxs))
# Out:
# Number of training samples: 30259
# Number of validate samples: 7577

# %%
import random
random.seed(2022)
random.shuffle(train_idxs)

# When run on a small RAM machine, you can set use_cache=False to 
# not run out of memory but it will slow down the training speed
train_tf_dataset = data_handler.prepare_tf_dataset(train_idxs, BATCH_SIZE, drop_remainder=True)
valid_tf_dataset = data_handler.prepare_tf_dataset(valid_idxs, BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# ## Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping_callback = EarlyStopping(
    monitor = 'val_loss', 
    min_delta = 1e-3, # Change that less than 1e-3, will count as no improvement
    patience = 5, # Stop if no improvement after 5 epochs
    restore_best_weights = True, # Restore weights from the epoch with the best value
    verbose = 1
)

# Reduce the learning rate once learning stagnates
reduce_lr_callback = ReduceLROnPlateau(
    monitor = 'val_loss', 
    patience = 2, # Reduce if no improvement after 2 epochs
    min_lr = 1e-6, # Lower bound on the learning rate 
    factor = 0.5, # => new_lr = lr * factor
    verbose = 1
)

# %% [markdown]
# ## Train the NomNaOCR dataset

# %%
from losses import MaskedLoss
from metrics import SequenceAccuracy, CharacterAccuracy, LevenshteinDistance
from tensorflow.keras.optimizers import Adam
LEARNING_RATE = 2e-4
EPOCHS = 100

# %%
model.compile(
    optimizer = Adam(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [ 
        SequenceAccuracy(), 
        CharacterAccuracy(),  
        LevenshteinDistance(normalize=True, name='lev_distance')
    ]
)

# %%
# %%time
history = model.fit(
    train_tf_dataset,
    validation_data = valid_tf_dataset,
    epochs = EPOCHS,
    callbacks = [reduce_lr_callback, early_stopping_callback],
    verbose = 1
).history
# Out:
# Epoch 1/100
# 945/945 [==============================] - 250s 239ms/step - loss: 4.8621 - seq_acc: 1.6534e-04 - char_acc: 0.0916 - lev_distance: 0.8174 - val_loss: 1.5456 - val_seq_acc: 0.0000e+00 - val_char_acc: 0.0952 - val_lev_distance: 0.7846 - lr: 2.0000e-04
# Epoch 2/100
# 945/945 [==============================] - 214s 226ms/step - loss: 4.5836 - seq_acc: 0.0029 - char_acc: 0.1256 - lev_distance: 0.7833 - val_loss: 1.3810 - val_seq_acc: 0.0029 - val_char_acc: 0.1482 - val_lev_distance: 0.7756 - lr: 2.0000e-04
# Epoch 3/100
# 945/945 [==============================] - 213s 225ms/step - loss: 4.4159 - seq_acc: 0.0042 - char_acc: 0.1472 - lev_distance: 0.7751 - val_loss: 1.3806 - val_seq_acc: 0.0036 - val_char_acc: 0.1556 - val_lev_distance: 0.7691 - lr: 2.0000e-04
# Epoch 4/100
# 945/945 [==============================] - 212s 225ms/step - loss: 4.2444 - seq_acc: 0.0062 - char_acc: 0.1627 - lev_distance: 0.7647 - val_loss: 1.3413 - val_seq_acc: 0.0075 - val_char_acc: 0.1524 - val_lev_distance: 0.7528 - lr: 2.0000e-04
# Epoch 5/100
# 945/945 [==============================] - 213s 226ms/step - loss: 4.0474 - seq_acc: 0.0086 - char_acc: 0.1811 - lev_distance: 0.7506 - val_loss: 1.2936 - val_seq_acc: 0.0119 - val_char_acc: 0.1878 - val_lev_distance: 0.7408 - lr: 2.0000e-04
# Epoch 6/100
# 945/945 [==============================] - 214s 226ms/step - loss: 3.8368 - seq_acc: 0.0104 - char_acc: 0.1964 - lev_distance: 0.7382 - val_loss: 1.3843 - val_seq_acc: 0.0132 - val_char_acc: 0.2037 - val_lev_distance: 0.7368 - lr: 2.0000e-04
# Epoch 7/100
# 945/945 [==============================] - ETA: 0s - loss: 3.6339 - seq_acc: 0.0132 - char_acc: 0.2141 - lev_distance: 0.7235
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 945/945 [==============================] - 213s 225ms/step - loss: 3.6341 - seq_acc: 0.0132 - char_acc: 0.2141 - lev_distance: 0.7235 - val_loss: 1.3237 - val_seq_acc: 0.0150 - val_char_acc: 0.2143 - val_lev_distance: 0.7259 - lr: 2.0000e-04
# Epoch 8/100
# 945/945 [==============================] - 215s 227ms/step - loss: 3.4109 - seq_acc: 0.0186 - char_acc: 0.2413 - lev_distance: 0.6979 - val_loss: 1.2284 - val_seq_acc: 0.0187 - val_char_acc: 0.2237 - val_lev_distance: 0.7153 - lr: 1.0000e-04
# Epoch 9/100
# 945/945 [==============================] - 215s 228ms/step - loss: 3.2728 - seq_acc: 0.0214 - char_acc: 0.2543 - lev_distance: 0.6850 - val_loss: 1.2247 - val_seq_acc: 0.0191 - val_char_acc: 0.2330 - val_lev_distance: 0.7089 - lr: 1.0000e-04
# Epoch 10/100
# 945/945 [==============================] - 215s 228ms/step - loss: 3.1589 - seq_acc: 0.0228 - char_acc: 0.2654 - lev_distance: 0.6738 - val_loss: 1.2387 - val_seq_acc: 0.0199 - val_char_acc: 0.2365 - val_lev_distance: 0.7053 - lr: 1.0000e-04
# Epoch 11/100
# 945/945 [==============================] - ETA: 0s - loss: 3.1080 - seq_acc: 0.0248 - char_acc: 0.2700 - lev_distance: 0.6669
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 945/945 [==============================] - 216s 228ms/step - loss: 3.1083 - seq_acc: 0.0248 - char_acc: 0.2700 - lev_distance: 0.6669 - val_loss: 1.2666 - val_seq_acc: 0.0222 - val_char_acc: 0.2408 - val_lev_distance: 0.7011 - lr: 1.0000e-04
# Epoch 12/100
# 945/945 [==============================] - 215s 227ms/step - loss: 2.9681 - seq_acc: 0.0302 - char_acc: 0.2934 - lev_distance: 0.6430 - val_loss: 1.2669 - val_seq_acc: 0.0242 - val_char_acc: 0.2517 - val_lev_distance: 0.6903 - lr: 5.0000e-05
# Epoch 13/100
# 945/945 [==============================] - ETA: 0s - loss: 2.8672 - seq_acc: 0.0323 - char_acc: 0.3064 - lev_distance: 0.6301
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 945/945 [==============================] - 215s 228ms/step - loss: 2.8674 - seq_acc: 0.0323 - char_acc: 0.3064 - lev_distance: 0.6301 - val_loss: 1.2733 - val_seq_acc: 0.0233 - val_char_acc: 0.2544 - val_lev_distance: 0.6883 - lr: 5.0000e-05
# Epoch 14/100
# 945/945 [==============================] - ETA: 0s - loss: 2.7875 - seq_acc: 0.0350 - char_acc: 0.3204 - lev_distance: 0.6154Restoring model weights from the end of the best epoch: 9.
# 945/945 [==============================] - 215s 227ms/step - loss: 2.7878 - seq_acc: 0.0350 - char_acc: 0.3204 - lev_distance: 0.6154 - val_loss: 1.2857 - val_seq_acc: 0.0241 - val_char_acc: 0.2600 - val_lev_distance: 0.6848 - lr: 2.5000e-05
# Epoch 14: early stopping
# CPU times: total: 1h 4min 47s
# Wall time: 50min 34s

# %% [markdown]
# ## Save the training results

# %%
best_epoch = early_stopping_callback.best_epoch
print(f'- Loss on validation\t: {history["val_loss"][best_epoch]}')
print(f'- Sequence accuracy\t: {history["val_seq_acc"][best_epoch]}')
print(f'- Character accuracy\t: {history["val_char_acc"][best_epoch]}')
print(f'- Levenshtein distance\t: {history["val_lev_distance"][best_epoch]}')
# Out:
# - Loss on validation	: 1.2246545553207397
# - Sequence accuracy	: 0.0190677959471941
# - Character accuracy	: 0.2329501509666443
# - Levenshtein distance	: 0.7089225649833679

# %%
from visualizer import plot_training_results
plot_training_results(history, f'{APPROACH_NAME}.png')
model.cnn_block.save_weights(f'{APPROACH_NAME}_cnn.h5')
model.rnn_block.save_weights(f'{APPROACH_NAME}_rnn.h5')

# %% [markdown]
# # Inference

# %%
cnn_block = FeaturesExtractor(imagenet_model, imagenet_output_layer)
rnn_block = TextProcessor(cnn_block.output.shape[1:])
cnn_block.load_weights(f'NomNaOCR/NomNaOCR_{APPROACH_NAME}_cnn.h5')
rnn_block.load_weights(f'NomNaOCR/NomNaOCR_{APPROACH_NAME}_rnn.h5')

# %%
reset_model = EarlyBindingCaptioner(cnn_block, rnn_block, data_handler)
reset_model.compile(
    optimizer = Adam(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [
        SequenceAccuracy(),
        CharacterAccuracy(),
        LevenshteinDistance(normalize=True, name='lev_distance')
    ]
)

# %% [markdown]
# ## On test dataset

# %%
for idx, (batch_images, batch_tokens) in enumerate(valid_tf_dataset.take(1)):
    idxs_in_batch = valid_idxs[idx * BATCH_SIZE: (idx + 1) * BATCH_SIZE]
    labels = data_handler.tokens2texts(batch_tokens)
    pred_tokens = reset_model.predict(batch_images)
    pred_labels = data_handler.tokens2texts(pred_tokens)
    
    visualize_images_labels(
        img_paths = dataset.img_paths[idxs_in_batch], 
        labels = labels, 
        pred_labels = pred_labels,
        figsize = (11.6, 30),
        subplot_size = (4, 8),
        legend_loc = (3.8, 4.38),
        annotate_loc = (4, 2.75),
        font_path = FONT_PATH, 
    )
    print(
        f'Batch {idx + 1:02d}:\n'
        f'- True: {dict(enumerate(labels, start=1))}\n'
        f'- Pred: {dict(enumerate(pred_labels, start=1))}\n'
    )
# Out:
# Batch 01:
# - True: {1: '使通好執事迷而不反我是以有徃年之師帝遣', 2: '池有大蛇入見二十日上以砲旗皷制之賜月', 3: '非傾人宗祧若是其幾無所不至以致大明之疑', 4: '十一月戊辰朔日有食以裴時亨密奏故不之', 5: '使人追之不及十三日卯時克終自元軍回賊', 6: '冬十一月皇太子即皇帝位大赦以明年爲景', 7: '於民何以居人上宜早除之帝自知其然而心', 8: '使養之其人曰每月用藥所費百金三年方效王', 9: '一士王之時雖有守任然王以諸侯當國國人皆', 10: '安生王子國峻奪之公主㱕于國峻是月十五日', 11: '項郎尤鍾愛之立爲太子璉以是不平使人陰殺', 12: '其才品有高下之不同然亦莫不各得其人以', 13: '是龍鋌求爲太子帝欲許之廷臣議以爲不立長', 14: '取陶儼等三十六人廷試上親問以君師之道', 15: '日還國雖曰人謀之不滅是亦天運之有数也夫', 16: '之以本月十九日遷塟于御天之羙舍鄕二十', 17: '博覽副之卒定三年一貢為常例二月二十四', 18: '京恐為不便帝從之故有是命令明人著京', 19: '鄕人也以太祖起義六年癸卯冬十一月二', 20: '献六眸龟胷中有籒文二行群臣辨之成王以公', 21: '為阮朝且絶民之望李氏也秋七月二十二日', 22: '柰等二十員人入鳯\U000f0029堂帝自命題試之九日', 23: '府每以日燏子孫爲之如國康之於演州是也', 24: '納之乃拜二人為鎮殿副將軍令五府軍以陣圖', 25: '進上皇嘉之賜田四十𤱈以為後日脩行之資延', 26: '二十七日旨社置社官大社一百人以上用三', 27: '精氣因結為此故也世人以不常見而異之殊', 28: '元豊年間木印帖子者閲定官以為僞上皇聞之', 29: '天子之兆至是帝以甲戌年生為天子果', 30: '夏四月旱二十三日祈于昊天上帝以自冬迄', 31: '之曰何日擒獲䦕内人其事始和帝知意不解', 32: '甚長非我國之灾復命終宴是年冬十月宋帝崩'}
# - Pred: {1: '國帝帝為帝帝以不以也以不以帝不之帝帝國', 2: '而以大於下四十十日日日後後震後日日日', 3: '國國下以國其以不能然其不天不母天是之我', 4: '十十月日帝帝日以時山帝有以然帝而之不', 5: '不不不人人也十十月帝皇帝城至占是至城', 6: '十月月月日日日皇皇皇皇太崩宗宗元慈帝', 7: '也而而不也曰曰以曰國曰帝以也而然也不', 8: '城城之年下下而人而城以陛年帝日日年城上', 9: '一一一曰帝為之之人帝上子為為為為為人帝', 10: '皇王下王國德帝天帝王也王帝國也王二日日', 11: '國國天國國天以國下天母天以不天國天國國', 12: '不人不不者人人不不然而有不不得有下不', 13: '是是國宗帝王王帝帝帝王宗之為以為之天以', 14: '為分分分十十十十人為人為得之以罪之後', 15: '之之國無曰天而天下於而不不悅不心也也不', 16: '二二十十十十月第帝日位日日帝帝條十年', 17: '爲爲州十之冬十二十之帝為冬二十十日', 18: '者者者不者故故人故不有有有如下事命', 19: '以天以天天宗赦赦天天皇赦冬十十十十', 20: '人人公爲為中中公一一萬帝之萬之其人人', 21: '為以為以改不之以以之也冬二二十十月月', 22: '秋冬十十四十下帝帝命命以也故故冬冬月', 23: '帝帝日一帝曰國帝之以帝帝之也於而也也', 24: '之之之以一人為為為衛為軍令入軍軍人州都', 25: '之之之帝之萬之一一萬之萬帝曰無以曰於也', 26: '十月月日旨城明明有一有一一一以一四一', 27: '國國不國所不所而而人人不於不不而之也', 28: '皇皇太帝皇帝宗子宗帝以子子為為上之為之', 29: '王王宗位皇皇位皇子位子子崩皇子以', 30: '冬十十十十十月月帝日日日天帝至至帝帝', 31: '二二日日德無於天下不而所而所有為不然', 32: '其以其於於之以城其城是是天至月月皇帝國'}

# %% [markdown]
# ## On random image

# %%
random_path = '../囷𦝄苔惮󰞺𧍋𦬑囊.jpg'
random_label = '囷𦝄苔惮󰞺𧍋𦬑囊'
random_image = data_handler.process_image(random_path)
pred_tokens = reset_model.predict(tf.expand_dims(random_image, axis=0))
pred_labels = data_handler.tokens2texts(pred_tokens)

# %%
visualize_images_labels(
    img_paths = [random_path], 
    labels = [random_label], 
    pred_labels = pred_labels,
    figsize = (5, 4),
    subplot_size = (1, 1), 
    font_path = FONT_PATH, 
)
print('Predicted text:', ''.join(pred_labels))
# Out:
# Predicted text: 𠊛𠊛買別細𢚸𢚸愁

# %% [markdown]
# # Detail evaluation

# %%
import pandas as pd
from evaluator import Evaluator
GT10_TRANSCRIPTS_PATH = f'{DATASET_DIR}/Validate_gt10.txt'
LTE10_TRANSCRIPTS_PATH = f'{DATASET_DIR}/Validate_lte10.txt'

# %%
gt10_evaluator = Evaluator(reset_model, DATASET_DIR, GT10_TRANSCRIPTS_PATH)
lte10_evaluator = Evaluator(reset_model, DATASET_DIR, LTE10_TRANSCRIPTS_PATH)
df = pd.DataFrame([
    reset_model.evaluate(valid_tf_dataset, return_dict=True),
    gt10_evaluator.evaluate(data_handler, BATCH_SIZE, drop_remainder=True),
    lte10_evaluator.evaluate(data_handler, BATCH_SIZE, drop_remainder=True),
])
df.index = ['Full', 'Length > 10', 'Length ≤ 10']
df
# Out:
# 236/236 [==============================] - 43s 129ms/step - loss: 3.1299 - seq_acc: 0.0191 - char_acc: 0.2330 - lev_distance: 0.7089
# 120/120 [==============================] - 16s 129ms/step - loss: 3.9805 - seq_acc: 0.0000e+00 - char_acc: 0.1879 - lev_distance: 0.8062
# 116/116 [==============================] - 15s 126ms/step - loss: 1.6344 - seq_acc: 0.0388 - char_acc: 0.3494 - lev_distance: 0.6058
#                  loss   seq_acc  char_acc  lev_distance
# Full         1.224655  0.019068  0.232950      0.708923
# Length > 10  4.772167  0.000000  0.187931      0.806201
# Length ≤ 10  1.362206  0.038793  0.349396      0.605805
