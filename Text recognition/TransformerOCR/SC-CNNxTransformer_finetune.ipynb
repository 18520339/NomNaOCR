# %%
# https://www.tensorflow.org/text/tutorials/transformer
# https://keras.io/examples/nlp/neural_machine_translation_with_transformer
# https://keras.io/examples/vision/image_captioning
import sys
import tensorflow as tf
sys.path.append('..')
tf.get_logger().setLevel('ERROR')
APPROACH_NAME = 'SC-CNNxTransformer'

# %% [markdown]
# # Check GPU working

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)
# !nvcc -V
# Out:
# Found GPU at: /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:15:10_Pacific_Standard_Time_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0

# %% [markdown]
# # Data input pipeline

# %%
DATASET_DIR = r'../../Datasets/Patches'
LABELS_PATH = r'../../Datasets/Patches/Labels.txt'
FONT_PATH = r'../../NomNaTong-Regular.ttf'

# %% [markdown]
# ## Load and remove records with rare characters

# %%
from loader import DataImporter
dataset = DataImporter(DATASET_DIR, LABELS_PATH, min_length=1).remove_rare_chars(1)
print(dataset)
# Out:
# Samples count (not include Latin letters, numbers, punctuations):
# - Number of images found: 37836
# - Number of labels found: 37836
# - Number of unique characters: 7479
# - Characters present: {'之': 7523, '以': 4796, '人': 3550, '月': 3446, '十': 3252, '不': 3145, '年': 3012, '帝': 2689, '有': 2541, '二': 2492, '其': 2449, '大': 2312, '日': 2260, '為': 2228, '等': 2082, '爲': 2018, '而': 1973, '國': 1946, '一': 1931, '軍': 1880, '王': 1872, '太': 1871, '公': 1830, '天': 1829, '子': 1792, '三': 1784, '官': 1783, '兵': 1778, '明': 1721, '曰': 1680, '於': 1629, '至': 1625, '使': 1597, '時': 1562, '者': 1561, '阮': 1550, '事': 1521, '臣': 1519, '也': 1498, '黎': 1409, '及': 1384, '文': 1374, '皇': 1359, '上': 1358, '如': 1352, '是': 1299, '行': 1258, '安': 1250, '五': 1240, '士': 1240, '中': 1217, '元': 1207, '四': 1199, '命': 1166, '下': 1165, '自': 1161, '民': 1120, '所': 1113, '宗': 1095, '書': 1047, '州': 1044, '六': 1029, '得': 1028, '道': 1015, '武': 1008, '于': 999, '生': 988, '都': 957, '吏': 946, '城': 939, '正': 922, '将': 907, '知': 899, '各': 889, '令': 884, '入': 881, '進': 880, '㐌': 871, '山': 871, '無': 869, '郡': 857, '史': 854, '後': 845, '諸': 845, '春': 842, '朝': 834, '名': 831, '部': 827, '内': 826, '出': 821, '陳': 814, '八': 792, '南': 788, '七': 784, '外': 780, '平': 773, '同': 768, '乃': 766, '府': 752, '遣': 736, '家': 732, '莫': 727, '在': 719, '師': 707, '德': 693, '鄭': 688, '司': 687, '定': 687, '則': 684, '朱': 683, '本': 679, '故': 679, '御': 677, '又': 671, '可': 671, '先': 668, '百': 667, '身': 664, '未': 653, '九': 651, '制': 651, '方': 650, '東': 643, '前': 642, '禮': 640, '浪': 638, '從': 630, '守': 629, '分': 628, '賊': 628, '立': 625, '娘': 622, '長': 620, '政': 616, '來': 615, '初': 612, '今': 609, '宋': 605, '江': 601, '世': 596, '固': 593, '門': 588, '見': 588, '此': 583, '縣': 582, '與': 581, '功': 579, '侯': 576, '情': 574, '相': 572, '用': 571, '言': 570, '詔': 569, '皆': 569, '清': 567, '興': 562, '\U000f047c': 561, '賜': 559, '復': 554, '奏': 551, '𢚸': 548, '侍': 547, '京': 546, '地': 542, '水': 542, '秋': 542, '拱': 540, '郎': 539, '心': 534, '位': 533, '左': 532, '群': 531, '罪': 530, '仁': 527, '尼': 525, '死': 522, '督': 515, '海': 515, '西': 515, '然': 511, '金': 510, '\U000f070b': 505, '殿': 503, '處': 501, '光': 500, '餘': 499, '領': 498, '主': 498, '我': 496, '衛': 495, '聖': 490, '𦋦': 488, '萬': 485, '封': 485, '還': 484, '多': 481, '路': 480, '奉': 467, '成': 465, '女': 465, '𠳒': 463, '后': 461, '化': 460, '保': 460, '親': 459, '花': 459, '𠬠': 457, '買': 450, '即': 447, '作': 447, '占': 447, '治': 447, '冬': 445, '𠊛': 444, '北': 440, '何': 439, '將': 437, '吳': 433, '林': 432, '節': 432, '義': 431, '夏': 428, '監': 427, '漢': 425, '差': 423, '馬': 423, '亦': 413, '卒': 410, '當': 408, '君': 408, '夫': 406, '重': 406, '神': 405, '矣': 404, '試': 401, '仍': 399, '右': 398, '宫': 396, '順': 396, '營': 395, '鎮': 393, '氏': 392, '埃': 391, '丁': 389, '李': 389, '居': 388, '強': 388, '院': 387, '殺': 387, '麻': 385, '少': 384, '常': 381, '回': 380, '會': 379, '法': 378, '畧': 375, '能': 372, '已': 372, '范': 371, '聞': 363, '廷': 360, '職': 358, '並': 357, '廣': 356, '陽': 356, '改': 356, '取': 354, '龍': 352, '刑': 350, '芇': 348, '通': 348, '承': 348, '非': 345, '經': 344, '黄': 343, '祖': 342, '號': 342, '欲': 340, '或': 336, '尚': 335, '土': 335, '社': 334, '科': 334, '宜': 334, '稱': 334, '連': 333, '伯': 331, '若': 331, '小': 330, '宣': 329, '永': 328, '登': 327, '福': 325, '牢': 324, '忠': 324, '副': 323, '欺': 323, '因': 322, '杜': 320, '率': 319, '降': 318, '船': 318, '許': 317, '眾': 317, '旨': 316, '問': 316, '別': 316, '意': 315, '頭': 315, '才': 315, '參': 313, '田': 313, '服': 312, '交': 312, '風': 311, '勑': 308, '父': 307, '察': 307, '遂': 304, '甲': 303, '威': 303, '𠓨': 302, '開': 302, '尉': 301, '學': 300, '嘉': 299, '應': 299, '象': 298, '憲': 297, '攻': 297, '惟': 295, '和': 295, '𡗶': 293, '謂': 293, '過': 293, '華': 293, '除': 292, '原': 292, '典': 291, '信': 290, '第': 290, '必': 290, '克': 289, '諭': 286, '直': 285, '起': 283, '越': 283, '實': 282, '置': 282, '兼': 282, '千': 282, '物': 281, '户': 281, '統': 279, '特': 278, '調': 278, '爵': 277, '敬': 277, '數': 277, '茹': 273, '爫': 272, '乎': 272, '傷': 271, '受': 271, '寺': 270, '終': 270, '擊': 269, '間': 268, '古': 268, '真': 268, '任': 267, '送': 266, '論': 265, '總': 265, '姓': 265, '度': 264, '征': 262, '力': 262, '浽': 259, '塘': 259, '并': 258, '䏻': 258, '凣': 258, '戰': 257, '払': 256, '食': 256, '失': 256, '禁': 255, '饒': 254, '求': ...

# %% [markdown]
# ## Data constants and input pipeline

# %%
HEIGHT, WIDTH = 432, 48
PADDING_CHAR = '[PAD]' 
START_CHAR = '[START]'
END_CHAR = '[END]'

# %%
from loader import DataHandler
data_handler = DataHandler(
    dataset, 
    img_size = (HEIGHT, WIDTH), 
    padding_char = PADDING_CHAR,
    start_char = START_CHAR,
    end_char = END_CHAR
)

# %%
MAX_LENGTH = data_handler.max_length
START_TOKEN = data_handler.start_token
END_TOKEN = data_handler.end_token
VOCAB_SIZE = data_handler.char2num.vocab_size()
BATCH_SIZE = 32

# %% [markdown]
# ## Visualize the data

# %%
from visualizer import visualize_images_labels
visualize_images_labels(
    dataset.img_paths, 
    dataset.labels, 
    figsize = (15, 15),
    subplot_size = (2, 8),
    font_path = FONT_PATH
)

# %% [markdown]
# # Define model components

# %%
from tensorflow.keras.layers import Input
from layers import custom_cnn, reshape_features
from transformer import TransformerEncoderBlock, TransformerDecoderBlock

# %% [markdown]
# ## Features extraction

# %%
def get_cnn_model(imagenet_model=None, imagenet_output_layer=None, name='CNN_model'):
    if imagenet_model: # Use Imagenet model as CNN layers
        image_input = imagenet_model.input
        imagenet_model.layers[0]._name = 'image'
        x = imagenet_model.get_layer(imagenet_output_layer).output
    else: 
        image_input = Input(shape=(HEIGHT, WIDTH, 3), dtype='float32', name='image')
        conv_blocks_config = {
            'block1': {'num_conv': 1, 'filters':  64, 'pool_size': (2, 2)}, 
            'block2': {'num_conv': 1, 'filters': 128, 'pool_size': (2, 2)}, 
            'block3': {'num_conv': 2, 'filters': 256, 'pool_size': (2, 2)}, 
            'block4': {'num_conv': 2, 'filters': 512, 'pool_size': (2, 2)}, 
            
            # Last Conv blocks with 2x2 kernel but without no padding and pooling layer
            'block5': {'num_conv': 2, 'filters': 512, 'pool_size': None}, 
        }
        x = custom_cnn(conv_blocks_config, image_input)
    
    # Reshape accordingly before passing output to the Transformer encoder
    feature_maps = reshape_features(x, dim_to_keep=1)
    return tf.keras.Model(inputs=image_input, outputs=feature_maps, name=name)

# %%
from models import get_imagenet_model
imagenet_model, imagenet_output_layer = None, None
# # Pick a model from https://keras.io/api/applications
# imagenet_model = get_imagenet_model('VGG16', (HEIGHT, WIDTH, 3))
# imagenet_output_layer = 'block5_pool'
# imagenet_model.summary(line_length=100)

# %% [markdown]
# ## Transformer encoder and decoder

# %%
NUM_LAYERS = 2
NUM_HEADS = 1
EMBEDDING_DIM = 512 # d_model
FEED_FORWARD_UNITS = 512 # dff
DROPOUT_RATE = 0.1

# %%
cnn_model = get_cnn_model(imagenet_model, imagenet_output_layer)
encoder = TransformerEncoderBlock(
    receptive_size = cnn_model.layers[-1].output_shape[-2],
    num_layers = NUM_LAYERS, # N encoder layers
    num_heads = NUM_HEADS,
    embedding_dim = EMBEDDING_DIM, # d_model
    feed_forward_units = FEED_FORWARD_UNITS, # dff
    dropout_rate = DROPOUT_RATE,
    use_skip_connection = True
)
decoder = TransformerDecoderBlock(
    enc_shape = encoder.output_shape[1:], # (receptive_size, enc_channels)
    seq_length = MAX_LENGTH - 1, # The inputs is shifted by 1
    vocab_size = VOCAB_SIZE,
    num_layers = NUM_LAYERS, # N decoder layers
    num_heads = NUM_HEADS,
    embedding_dim = EMBEDDING_DIM, # d_model
    feed_forward_units = FEED_FORWARD_UNITS, # dff
    dropout_rate = DROPOUT_RATE,
)

# %% [markdown]
# # Build the model

# %%
cnn_model.load_weights(f'./IHR-NomDB/IHR-NomDB_{APPROACH_NAME}_cnn.h5')
encoder.load_weights(f'./IHR-NomDB/IHR-NomDB_{APPROACH_NAME}_enc.h5')
decoder.load_weights(
    f'./IHR-NomDB/IHR-NomDB_{APPROACH_NAME}_dec.h5', 
    skip_mismatch = True,
    by_name = True,
)

# %%
from transformer import TransformerOCR
model = TransformerOCR(cnn_model, encoder, decoder, data_handler)
cnn_model.summary(line_length=90)
print()
encoder.summary(line_length=110)
print()
decoder.summary(line_length=110)
print()
# Out:
# Model: "CNN_model"
# __________________________________________________________________________________________
#  Layer (type)                           Output Shape                        Param #
# ==========================================================================================
#  image (InputLayer)                     [(None, 432, 48, 3)]                0
#
#  block1_conv1 (Conv2D)                  (None, 432, 48, 64)                 1792
#
#  block1_bn1 (BatchNormalization)        (None, 432, 48, 64)                 256
#
#  block1_relu1 (Activation)              (None, 432, 48, 64)                 0
#
#  block1_pool (MaxPooling2D)             (None, 216, 24, 64)                 0
#
#  block2_conv1 (Conv2D)                  (None, 216, 24, 128)                73856
#
#  block2_bn1 (BatchNormalization)        (None, 216, 24, 128)                512
#
#  block2_relu1 (Activation)              (None, 216, 24, 128)                0
#
#  block2_pool (MaxPooling2D)             (None, 108, 12, 128)                0
#
#  block3_conv1 (Conv2D)                  (None, 108, 12, 256)                295168
#
#  block3_bn1 (BatchNormalization)        (None, 108, 12, 256)                1024
#
#  block3_relu1 (Activation)              (None, 108, 12, 256)                0
#
#  block3_conv2 (Conv2D)                  (None, 108, 12, 256)                590080
#
#  block3_bn2 (BatchNormalization)        (None, 108, 12, 256)                1024
#
#  block3_relu2 (Activation)              (None, 108, 12, 256)                0
#
#  block3_pool (MaxPooling2D)             (None, 54, 6, 256)                  0
#
#  block4_conv1 (Conv2D)                  (None, 54, 6, 512)                  1180160
#
#  block4_bn1 (BatchNormalization)        (None, 54, 6, 512)                  2048
#
#  block4_relu1 (Activation)              (None, 54, 6, 512)                  0
#
#  block4_conv2 (Conv2D)                  (None, 54, 6, 512)                  2359808
#
#  block4_bn2 (BatchNormalization)        (None, 54, 6, 512)                  2048
#
#  block4_relu2 (Activation)              (None, 54, 6, 512)                  0
#
#  block4_pool (MaxPooling2D)             (None, 27, 3, 512)                  0
#
#  block5_conv1 (Conv2D)                  (None, 26, 2, 512)                  1049088
#
#  block5_bn1 (BatchNormalization)        (None, 26, 2, 512)                  2048
#
#  block5_relu1 (Activation)              (None, 26, 2, 512)                  0
#
#  block5_conv2 (Conv2D)                  (None, 25, 1, 512)                  1049088
#
#  block5_bn2 (BatchNormalization)        (None, 25, 1, 512)                  2048
#
#  block5_relu2 (Activation)              (None, 25, 1, 512)                  0
#
#  cnn_features (Reshape)                 (None, 25, 512)                     0
#
# ==========================================================================================
# Total params: 6,610,048
# Trainable params: 6,604,544
# Non-trainable params: 5,504
# __________________________________________________________________________________________
#
# Model: "TransformerEncoderBlock"
# ______________________________________________________________________________________________________________
#  Layer (type)                       Output Shape            Param #      Connected to
# ==============================================================================================================
#  cnn_features (InputLayer)          [(None, 25, 512)]       0            []
#
#  PositionalEncoding (TransformerEmb  (None, 25, 512)        0            ['cnn_features[0][0]']
#  edding)
#
#  embedding_dropout (Dropout)        (None, 25, 512)         0            ['PositionalEncoding[0][0]']
#
#  Encoder1 (TransformerEncoderLayer)  (None, 25, 512)        1577984      ['embedding_dropout[0][0]']
#
#  Encoder2 (TransformerEncoderLayer)  (None, 25, 512)        1577984      ['Encoder1[0][0]']
#
#  skip_connection (Add)              (None, 25, 512)         0            ['cnn_features[0][0]',
#                                                                           'Encoder2[0][0]']
#
# ==============================================================================================================
# Total params: 3,155,968
# Trainable params: 3,155,968
# Non-trainable params: 0
# ______________________________________________________________________________________________________________
# Model: "TransformerDecoderBlock"
# ______________________________________________________________________________________________________________
#  Layer (type)                       Output Shape            Param #      Connected to
# ==============================================================================================================
#  decoder_sequence (InputLayer)      [(None, 25)]            0            []
#
#  TokEmbAndPosEncode (TransformerEmb  (None, 25, 512)        3831296      ['decoder_sequence[0][0]']
#  edding)
#
#  embedding_dropout (Dropout)        (None, 25, 512)         0            ['TokEmbAndPosEncode[0][0]']
#
#  encoder_output (InputLayer)        [(None, 25, 512)]       0            []
#
#  Decoder1 (TransformerDecoderLayer)  ((None, 25, 512),      2629632      ['embedding_dropout[0][0]',
#                                      (None, 1, 25, 25),                   'encoder_output[0][0]']
#                                      (None, 1, 25, 25))
#
#  Decoder2 (TransformerDecoderLayer)  ((None, 25, 512),      2629632      ['Decoder1[0][0]',
#                                      (None, 1, 25, 25),                   'encoder_output[0][0]']
#                                      (None, 1, 25, 25))
#
#  prediction (Dense)                 (None, 25, 7483)        3838779      ['Decoder2[0][0]']
#
# ==============================================================================================================
# Total params: 12,929,339
# Trainable params: 12,929,339
# Non-trainable params: 0
# ______________________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
train_idxs = list(range(30259))
valid_idxs = list(range(train_idxs[-1] + 1, dataset.size))
print('Number of training samples:', len(train_idxs))
print('Number of validate samples:', len(valid_idxs))
# Out:
# Number of training samples: 30259
# Number of validate samples: 7577

# %%
import random
random.seed(2022)
random.shuffle(train_idxs)

# When run on a small RAM machine, you can set use_cache=False to 
# not run out of memory but it will slow down the training speed
train_tf_dataset = data_handler.prepare_tf_dataset(train_idxs, BATCH_SIZE, drop_remainder=True)
valid_tf_dataset = data_handler.prepare_tf_dataset(valid_idxs, BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# ## Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping_callback = EarlyStopping(
    monitor = 'val_loss', 
    min_delta = 1e-3, # Change that less than 1e-3, will count as no improvement
    patience = 5, # Stop if no improvement after 5 epochs
    restore_best_weights = True, # Restore weights from the epoch with the best value
    verbose = 1
)

# %% [markdown]
# ## Fine-tuning the NomNaOCR dataset

# %%
from losses import MaskedLoss
from metrics import SequenceAccuracy, CharacterAccuracy, LevenshteinDistance
from tensorflow.keras.optimizers import Adadelta

# Adadelta tends to benefit from higher initial learning rate values compared to
# other optimizers. Here use 1.0 to match the exact form in the original paper
LEARNING_RATE = 1.0
EPOCHS = 100

# %%
model.compile(
    optimizer = Adadelta(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [
        SequenceAccuracy(),
        CharacterAccuracy(),
        LevenshteinDistance(normalize=True)
    ]
)

# %%
# %%time
history = model.fit(
    train_tf_dataset,
    validation_data = valid_tf_dataset,
    epochs = EPOCHS,
    callbacks = [early_stopping_callback],
    verbose = 1
).history
# Out:
# Epoch 1/100
# 945/945 [==============================] - 253s 251ms/step - loss: 5.0551 - seq_acc: 0.0107 - char_acc: 0.2239 - levenshtein_distance: 0.7684 - val_loss: 3.8576 - val_seq_acc: 0.0456 - val_char_acc: 0.5335 - val_levenshtein_distance: 0.3830
# Epoch 2/100
# 945/945 [==============================] - 230s 244ms/step - loss: 1.7988 - seq_acc: 0.0739 - char_acc: 0.6166 - levenshtein_distance: 0.3128 - val_loss: 2.4516 - val_seq_acc: 0.1016 - val_char_acc: 0.7166 - val_levenshtein_distance: 0.2414
# Epoch 3/100
# 945/945 [==============================] - 235s 248ms/step - loss: 1.1842 - seq_acc: 0.1346 - char_acc: 0.7333 - levenshtein_distance: 0.2182 - val_loss: 2.2096 - val_seq_acc: 0.1416 - val_char_acc: 0.7540 - val_levenshtein_distance: 0.2082
# Epoch 4/100
# 945/945 [==============================] - 229s 242ms/step - loss: 0.9033 - seq_acc: 0.1936 - char_acc: 0.7897 - levenshtein_distance: 0.1722 - val_loss: 1.6901 - val_seq_acc: 0.1688 - val_char_acc: 0.7752 - val_levenshtein_distance: 0.1832
# Epoch 5/100
# 945/945 [==============================] - 228s 241ms/step - loss: 0.7344 - seq_acc: 0.2500 - char_acc: 0.8277 - levenshtein_distance: 0.1420 - val_loss: 1.6724 - val_seq_acc: 0.1792 - val_char_acc: 0.7907 - val_levenshtein_distance: 0.1764
# Epoch 6/100
# 945/945 [==============================] - 229s 242ms/step - loss: 0.6030 - seq_acc: 0.3003 - char_acc: 0.8512 - levenshtein_distance: 0.1229 - val_loss: 1.7085 - val_seq_acc: 0.2058 - val_char_acc: 0.8104 - val_levenshtein_distance: 0.1607
# Epoch 7/100
# 945/945 [==============================] - 230s 243ms/step - loss: 0.4999 - seq_acc: 0.3542 - char_acc: 0.8727 - levenshtein_distance: 0.1048 - val_loss: 1.4909 - val_seq_acc: 0.2071 - val_char_acc: 0.8161 - val_levenshtein_distance: 0.1561
# Epoch 8/100
# 945/945 [==============================] - 232s 246ms/step - loss: 0.4229 - seq_acc: 0.3987 - char_acc: 0.8851 - levenshtein_distance: 0.0943 - val_loss: 1.5571 - val_seq_acc: 0.2166 - val_char_acc: 0.8309 - val_levenshtein_distance: 0.1532
# Epoch 9/100
# 945/945 [==============================] - 232s 246ms/step - loss: 0.3589 - seq_acc: 0.4466 - char_acc: 0.8981 - levenshtein_distance: 0.0822 - val_loss: 1.8727 - val_seq_acc: 0.1913 - val_char_acc: 0.7968 - val_levenshtein_distance: 0.1735
# Epoch 10/100
# 945/945 [==============================] - 234s 247ms/step - loss: 0.3049 - seq_acc: 0.5010 - char_acc: 0.9104 - levenshtein_distance: 0.0706 - val_loss: 1.9965 - val_seq_acc: 0.1970 - val_char_acc: 0.7976 - val_levenshtein_distance: 0.1724
# Epoch 11/100
# 945/945 [==============================] - 233s 246ms/step - loss: 0.2627 - seq_acc: 0.5387 - char_acc: 0.9179 - levenshtein_distance: 0.0637 - val_loss: 1.8936 - val_seq_acc: 0.1929 - val_char_acc: 0.8061 - val_levenshtein_distance: 0.1717
# Epoch 12/100
# 945/945 [==============================] - 233s 246ms/step - loss: 0.2353 - seq_acc: 0.5824 - char_acc: 0.9266 - levenshtein_distance: 0.0559 - val_loss: 1.4481 - val_seq_acc: 0.2362 - val_char_acc: 0.8339 - val_levenshtein_distance: 0.1460
# Epoch 13/100
# 945/945 [==============================] - 237s 251ms/step - loss: 0.2068 - seq_acc: 0.6119 - char_acc: 0.9328 - levenshtein_distance: 0.0513 - val_loss: 2.2623 - val_seq_acc: 0.2068 - val_char_acc: 0.8024 - val_levenshtein_distance: 0.1679
# Epoch 14/100
# 945/945 [==============================] - 235s 249ms/step - loss: 0.1831 - seq_acc: 0.6387 - char_acc: 0.9376 - levenshtein_distance: 0.0465 - val_loss: 2.3109 - val_seq_acc: 0.2251 - val_char_acc: 0.8164 - val_levenshtein_distance: 0.1584
# Epoch 15/100
# 945/945 [==============================] - 233s 247ms/step - loss: 0.1708 - seq_acc: 0.6509 - char_acc: 0.9381 - levenshtein_distance: 0.0456 - val_loss: 1.9345 - val_seq_acc: 0.2483 - val_char_acc: 0.8375 - val_levenshtein_distance: 0.1435
# Epoch 16/100
# 945/945 [==============================] - 235s 249ms/step - loss: 0.1536 - seq_acc: 0.6874 - char_acc: 0.9462 - levenshtein_distance: 0.0394 - val_loss: 1.8856 - val_seq_acc: 0.2119 - val_char_acc: 0.8117 - val_levenshtein_distance: 0.1614
# Epoch 17/100
# 945/945 [==============================] - ETA: 0s - loss: 0.1419 - seq_acc: 0.7108 - char_acc: 0.9518 - levenshtein_distance: 0.0359Restoring model weights from the end of the best epoch: 12.
# 945/945 [==============================] - 234s 248ms/step - loss: 0.1419 - seq_acc: 0.7108 - char_acc: 0.9518 - levenshtein_distance: 0.0359 - val_loss: 1.9326 - val_seq_acc: 0.2495 - val_char_acc: 0.8411 - val_levenshtein_distance: 0.1408
# Epoch 17: early stopping
# CPU times: total: 1h 13min 51s
# Wall time: 1h 6min 12s

# %% [markdown]
# ## Save the training results

# %%
best_epoch = early_stopping_callback.best_epoch
print(f'- Loss on validation\t: {history["val_loss"][best_epoch]}')
print(f'- Sequence accuracy\t: {history["val_seq_acc"][best_epoch]}')
print(f'- Character accuracy\t: {history["val_char_acc"][best_epoch]}')
print(f'- Levenshtein distance\t: {history["val_levenshtein_distance"][best_epoch]}')
# Out:
# - Loss on validation	: 1.4480634927749634
# - Sequence accuracy	: 0.236228808760643
# - Character accuracy	: 0.8338946104049683
# - Levenshtein distance	: 0.14601324498653412

# %%
from visualizer import plot_training_results
plot_training_results(history, f'finetune_{APPROACH_NAME}.png')
model.cnn_model.save_weights(f'finetune_{APPROACH_NAME}_cnn.h5')
model.encoder.save_weights(f'finetune_{APPROACH_NAME}_enc.h5')
model.decoder.save_weights(f'finetune_{APPROACH_NAME}_dec.h5')

# %% [markdown]
# # Inference

# %%
cnn_model = get_cnn_model(imagenet_model, imagenet_output_layer)
encoder = TransformerEncoderBlock(
    receptive_size = cnn_model.layers[-1].output_shape[-2],
    num_layers = NUM_LAYERS, # N encoder layers
    num_heads = NUM_HEADS,
    embedding_dim = EMBEDDING_DIM, # d_model
    feed_forward_units = FEED_FORWARD_UNITS, # dff
    dropout_rate = DROPOUT_RATE,
    use_skip_connection = True
)
decoder = TransformerDecoderBlock(
    enc_shape = encoder.output_shape[1:], # (receptive_size, enc_channels)
    seq_length = MAX_LENGTH - 1, # The inputs is shifted by 1
    vocab_size = VOCAB_SIZE,
    num_layers = NUM_LAYERS, # N decoder layers
    num_heads = NUM_HEADS,
    embedding_dim = EMBEDDING_DIM, # d_model
    feed_forward_units = FEED_FORWARD_UNITS, # dff
    dropout_rate = DROPOUT_RATE,
)

# %%
cnn_model.load_weights(f'finetune_{APPROACH_NAME}_cnn.h5')
encoder.load_weights(f'finetune_{APPROACH_NAME}_enc.h5')
decoder.load_weights(f'finetune_{APPROACH_NAME}_dec.h5')

# %%
reset_model = TransformerOCR(cnn_model, encoder, decoder, data_handler)
reset_model.compile(
    optimizer = Adadelta(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [
        SequenceAccuracy(),
        CharacterAccuracy(),
        LevenshteinDistance(normalize=True)
    ]
)
reset_model.evaluate(valid_tf_dataset)
# Out:
# 236/236 [==============================] - 46s 156ms/step - loss: 0.9967 - seq_acc: 0.2362 - char_acc: 0.8339 - levenshtein_distance: 0.1460
# [0.236228808760643,
#  0.8338946104049683,
#  0.14601324498653412,
#  1.4480634927749634]

# %% [markdown]
# ## On test dataset

# %%
batch_results = []
for idx, (batch_images, batch_tokens) in enumerate(valid_tf_dataset.take(1)):
    idxs_in_batch = valid_idxs[idx * BATCH_SIZE: (idx + 1) * BATCH_SIZE]
    labels = data_handler.tokens2texts(batch_tokens)
    pred_tokens, attentions = reset_model.predict(batch_images, return_attention=True)
    pred_labels = data_handler.tokens2texts(pred_tokens)
    
    batch_results.append({'true': labels, 'pred': pred_labels, 'attentions': attentions})
    visualize_images_labels(
        img_paths = dataset.img_paths[idxs_in_batch], 
        labels = labels, 
        pred_labels = pred_labels,
        figsize = (11.6, 30),
        subplot_size = (4, 8),
        legend_loc = (3.8, 4.38),
        annotate_loc = (4, 2.75),
        font_path = FONT_PATH, 
    )
    print(
        f'Batch {idx + 1:02d}:\n'
        f'- True: {dict(enumerate(labels, start=1))}\n'
        f'- Pred: {dict(enumerate(pred_labels, start=1))}\n'
    )
# Out:
# Batch 01:
# - True: {1: '使通好執事迷而不反我是以有徃年之師帝遣', 2: '池有大蛇入見二十日上以砲旗皷制之賜月', 3: '非傾人宗祧若是其幾無所不至以致大明之疑', 4: '十一月戊辰朔日有食以裴時亨密奏故不之', 5: '使人追之不及十三日卯時克終自元軍回賊', 6: '冬十一月皇太子即皇帝位大赦以明年爲景', 7: '於民何以居人上宜早除之帝自知其然而心', 8: '使養之其人曰每月用藥所費百金三年方效王', 9: '一士王之時雖有守任然王以諸侯當國國人皆', 10: '安生王子國峻奪之公主㱕于國峻是月十五日', 11: '項郎尤鍾愛之立爲太子璉以是不平使人陰殺', 12: '其才品有高下之不同然亦莫不各得其人以', 13: '是龍鋌求爲太子帝欲許之廷臣議以爲不立長', 14: '取陶儼等三十六人廷試上親問以君師之道', 15: '日還國雖曰人謀之不滅是亦天運之有数也夫', 16: '之以本月十九日遷塟于御天之羙舍鄕二十', 17: '博覽副之卒定三年一貢為常例二月二十四', 18: '京恐為不便帝從之故有是命令明人著京', 19: '鄕人也以太祖起義六年癸卯冬十一月二', 20: '献六眸龟胷中有籒文二行群臣辨之成王以公', 21: '為阮朝且絶民之望李氏也秋七月二十二日', 22: '柰等二十員人入鳯\U000f0029堂帝自命題試之九日', 23: '府每以日燏子孫爲之如國康之於演州是也', 24: '納之乃拜二人為鎮殿副將軍令五府軍以陣圖', 25: '進上皇嘉之賜田四十𤱈以為後日脩行之資延', 26: '二十七日旨社置社官大社一百人以上用三', 27: '精氣因結為此故也世人以不常見而異之殊', 28: '元豊年間木印帖子者閲定官以為僞上皇聞之', 29: '天子之兆至是帝以甲戌年生為天子果', 30: '夏四月旱二十三日祈于昊天上帝以自冬迄', 31: '之曰何日擒獲䦕内人其事始和帝知意不解', 32: '甚長非我國之灾復命終宴是年冬十月宋帝崩'}
# - Pred: {1: '使通好亂事迷而不父𦤶是以有徃年之師帝遣', 2: '池有大蛇入見二十日上以砲旗皷制之四月', 3: '非傾人宗桃若是其幾無所不至以致大明之疑', 4: '十一月戊辰朔日有食以裴時亨密奏故不之', 5: '使人追之不及十三日卯時克終自元軍回賊', 6: '冬十一月皇太子即皇帝位大赦以明年爲景', 7: '於民何以尼石人上宜旱除之帝自知其於而', 8: '使資之其人曰每月用藥所費百金三年方效上', 9: '一言王之時雖有守任然王以諸侯當國', 10: '父生王子國峻命之公主歸于國峻是月十五日', 11: '項郎尤鍾愛之立為太子璉以是不平使人峻殺', 12: '其才品有高下之不同然亦莫不各得唉人以', 13: '是龍鋌求爲太子帝欲許之廷臣議以為不立長', 14: '取陶儼等三十六人延試上親間以君師之道', 15: '日還國𨿽曰人謀之不减是亦天運之有必大', 16: '之以本月十九日還塟于御天之羙舍鄕二十', 17: '群覽副之卒定二年一貢為常例二月二四十四', 18: '京恐爲不使帝從之故有是命令明人着序', 19: '鄕人也以太祖起義六年癸卯冬十一月二', 20: '献六眸池骨中有稱文二行群臣辦之成王以公', 21: '爲阮朝且絶民之望李氏也秋七月二十二日', 22: '一等二十員人入鳳\U000f0029堂帝自命題試之九日', 23: '府每以日燏子孫為之如國康之於演州是北也', 24: '劎之乃拜二人為鎮殿副将軍令五府軍以陣圖', 25: '進上皇嘉之楊田四十畝以為後日脩行之資延', 26: '二十七日旨揮置社官大社一百人以上用二', 27: '持氣因結為此故也世人以不常見而異之殊', 28: '元置年間木印帖子者閲定官以為僞上皇聞之', 29: '天子之兆至是帝以甲戌年生為天子果', 30: '夏四月旱二十三日祈于是天上帝以自冬迨', 31: '之曰何日擒\U000f0c50開内人其事始和帝知意不解', 32: '甚長非我國之灾復命終宴是年冬十月宋帝崩'}

# %% [markdown]
# ## On random image

# %%
random_path = '../囷𦝄苔惮󰞺𧍋𦬑囊.jpg'
random_label = '囷𦝄苔惮󰞺𧍋𦬑囊'
random_image = data_handler.process_image(random_path)
pred_tokens = reset_model.predict(tf.expand_dims(random_image, axis=0))
pred_labels = data_handler.tokens2texts(pred_tokens)

# %%
visualize_images_labels(
    img_paths = [random_path], 
    labels = [random_label], 
    pred_labels = pred_labels,
    figsize = (5, 4),
    subplot_size = (1, 1), 
    font_path = FONT_PATH, 
)
print('Predicted text:', ''.join(pred_labels))
# Out:
# Predicted text: 同𦝄苔惮󰞺𧍋𦬑塞
