# %%
# https://github.com/bai-shang/crnn_seq2seq_ocr_pytorch
# https://github.com/chenjun2hao/Attention_ocr.pytorch
# https://github.com/alleveenstra/attentionocr
# https://github.com/koibiki/CRNN-ATTENTION
import sys
import tensorflow as tf
sys.path.append('..')
tf.get_logger().setLevel('ERROR')
APPROACH_NAME = 'SC-CNNxSeq2Seq'

# %% [markdown]
# # Check GPU working

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)
# !nvcc -V
# Out:
# Found GPU at: /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:15:10_Pacific_Standard_Time_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0

# %% [markdown]
# # Data input pipeline

# %%
DATASET_DIR = r'../../Datasets/Patches'
ALL_TRANSCRIPTS_PATH = f'{DATASET_DIR}/All.txt'
VALID_TRANSCRIPTS_PATH = f'{DATASET_DIR}/Validate.txt'
FONT_PATH = r'../../NomNaTong-Regular.ttf'

# %% [markdown]
# ## Load and remove records with rare characters

# %%
from loader import DataImporter
dataset = DataImporter(DATASET_DIR, ALL_TRANSCRIPTS_PATH, min_length=1)
print(dataset)
# Out:
# Samples count (not include Latin letters, numbers, punctuations):
# - Number of images found: 37836
# - Number of labels found: 37836
# - Number of unique characters: 7479
# - Characters present: {'之': 7523, '以': 4796, '人': 3550, '月': 3446, '十': 3252, '不': 3145, '年': 3012, '帝': 2689, '有': 2541, '二': 2492, '其': 2449, '大': 2312, '日': 2260, '為': 2228, '等': 2082, '爲': 2018, '而': 1973, '國': 1946, '一': 1931, '軍': 1880, '王': 1872, '太': 1871, '公': 1830, '天': 1829, '子': 1792, '三': 1784, '官': 1783, '兵': 1778, '明': 1721, '曰': 1680, '於': 1629, '至': 1625, '使': 1597, '時': 1562, '者': 1561, '阮': 1550, '事': 1521, '臣': 1519, '也': 1498, '黎': 1409, '及': 1384, '文': 1374, '皇': 1359, '上': 1358, '如': 1352, '是': 1299, '行': 1258, '安': 1250, '五': 1240, '士': 1240, '中': 1217, '元': 1207, '四': 1199, '命': 1166, '下': 1165, '自': 1161, '民': 1120, '所': 1113, '宗': 1095, '書': 1047, '州': 1044, '六': 1029, '得': 1028, '道': 1015, '武': 1008, '于': 999, '生': 988, '都': 957, '吏': 946, '城': 939, '正': 922, '将': 907, '知': 899, '各': 889, '令': 884, '入': 881, '進': 880, '㐌': 871, '山': 871, '無': 869, '郡': 857, '史': 854, '後': 845, '諸': 845, '春': 842, '朝': 834, '名': 831, '部': 827, '内': 826, '出': 821, '陳': 814, '八': 792, '南': 788, '七': 784, '外': 780, '平': 773, '同': 768, '乃': 766, '府': 752, '遣': 736, '家': 732, '莫': 727, '在': 719, '師': 707, '德': 693, '鄭': 688, '司': 687, '定': 687, '則': 684, '朱': 683, '本': 679, '故': 679, '御': 677, '又': 671, '可': 671, '先': 668, '百': 667, '身': 664, '未': 653, '九': 651, '制': 651, '方': 650, '東': 643, '前': 642, '禮': 640, '浪': 638, '從': 630, '守': 629, '分': 628, '賊': 628, '立': 625, '娘': 622, '長': 620, '政': 616, '來': 615, '初': 612, '今': 609, '宋': 605, '江': 601, '世': 596, '固': 593, '
# %% [markdown]
# ## Data constants and input pipeline

# %%
HEIGHT, WIDTH = 432, 48
PADDING_CHAR = '[PAD]' 
START_CHAR = '[START]'
END_CHAR = '[END]'

# %%
from loader import DataHandler
data_handler = DataHandler(
    dataset, 
    img_size = (HEIGHT, WIDTH), 
    padding_char = PADDING_CHAR,
    start_char = START_CHAR,
    end_char = END_CHAR
)

# %%
NUM_VALIDATE = DataImporter(DATASET_DIR, VALID_TRANSCRIPTS_PATH, min_length=1).size
START_TOKEN = data_handler.start_token
END_TOKEN = data_handler.end_token
VOCAB_SIZE = data_handler.char2num.vocab_size()
BATCH_SIZE = 32

# %% [markdown]
# ## Visualize the data

# %%
from visualizer import visualize_images_labels
visualize_images_labels(
    dataset.img_paths, 
    dataset.labels, 
    figsize = (15, 15),
    subplot_size = (2, 8),
    font_path = FONT_PATH
)

# %% [markdown]
# # Define model components

# %%
from tensorflow.keras.layers import (
    Input, Embedding, Dense, GRU, 
    Bidirectional, Concatenate, Flatten
)
from layers import custom_cnn, reshape_features, BahdanauAttention
EMBEDDING_DIM = 512
UNITS = 256

# %% [markdown]
# ## The encoder

# %%
def Encoder(imagenet_model=None, imagenet_output_layer=None, name='Encoder'):
    if imagenet_model: # Use Imagenet model as CNN layers
        image_input = imagenet_model.input
        imagenet_model.layers[0]._name = 'image'
        x = imagenet_model.get_layer(imagenet_output_layer).output
    else: 
        image_input = Input(shape=(HEIGHT, WIDTH, 3), dtype='float32', name='image')
        conv_blocks_config = {
            'block1': {'num_conv': 1, 'filters':  64, 'pool_size': (2, 2)}, 
            'block2': {'num_conv': 1, 'filters': 128, 'pool_size': (2, 2)}, 
            'block3': {'num_conv': 2, 'filters': 256, 'pool_size': (2, 2)}, 
            'block4': {'num_conv': 2, 'filters': 512, 'pool_size': (2, 2)}, 
            
            # Last Conv blocks with 2x2 kernel but without no padding and pooling layer
            'block5': {'num_conv': 2, 'filters': 512, 'pool_size': None}, 
        }
        x = custom_cnn(conv_blocks_config, image_input)

    # Reshape accordingly before passing output to RNN
    feature_maps = reshape_features(x, dim_to_keep=1, name='rnn_input')
    
    # RNN layers
    bigru1 = Bidirectional(GRU(UNITS, return_sequences=True), name='bigru1')(feature_maps)
    bigru2, forward_state, backward_state = Bidirectional(GRU(
        units = UNITS, 
        return_sequences = True,
        return_state = True
    ), name = 'bigru2')(bigru1)
    
    # Skip connection and concat states of 2 directions
    x = Concatenate(name='skip_connection')([feature_maps, bigru2])
    
    # Concat states of 2 directions
    final_state = Concatenate(name='encoder_state')([forward_state, backward_state])
    return tf.keras.Model(inputs=image_input, outputs=[x, final_state], name=name)

# %% [markdown]
# ## The decoder

# %%
def Decoder(enc_seq_shape, name='Decoder'):
    token_input = Input(shape=(1,), name='new_token')
    enc_seq_input = Input(shape=enc_seq_shape, name='encoder_sequence')
    
    # In encoder we used Bidirectional so we have to take double UNITS  
    # for single decoder GRU using encoder's final state as initial state
    dec_units = UNITS * 2
    pre_hidden_input = Input(shape=(dec_units,), name='previous_state')
    
    # Defining attention as a separate model
    attention = BahdanauAttention(dec_units)
    context_vector, attention_weights = attention(enc_seq_input, pre_hidden_input)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = Concatenate(axis=-1, name='context_and_embedding')([
        tf.expand_dims(context_vector, 1), 
        Embedding(VOCAB_SIZE, EMBEDDING_DIM)(token_input)
    ])
    
    # Passing the concatenated vector to the GRU
    rnn_output, state = GRU(
        units = dec_units, 
        return_state = True, 
        return_sequences = True,
        name = 'dec_gru'
    )(x, initial_state=pre_hidden_input)

    # Generate predictions
    x = Flatten()(rnn_output)
    y_pred = Dense(VOCAB_SIZE, name='prediction')(x)

    return tf.keras.Model(
        inputs = [token_input, enc_seq_input, pre_hidden_input], 
        outputs = [y_pred, state, attention_weights],
        name = name
    )

# %% [markdown]
# # Build the model

# %%
from models import get_imagenet_model, EncoderDecoderModel
imagenet_model, imagenet_output_layer = None, None
# # Pick a model from https://keras.io/api/applications
# imagenet_model = get_imagenet_model('VGG16', (HEIGHT, WIDTH, 3))
# imagenet_output_layer = 'block5_pool'
# imagenet_model.summary(line_length=100)

# %%
encoder = Encoder(imagenet_model, imagenet_output_layer)
decoder = Decoder(encoder.outputs[0].shape[1:])
encoder.load_weights(f'./IHR-NomDB/IHR-NomDB_{APPROACH_NAME}_enc.h5')
decoder.load_weights(
    f'./IHR-NomDB/IHR-NomDB_{APPROACH_NAME}_dec.h5', 
    skip_mismatch = True,
    by_name = True,
)

# %%
model = EncoderDecoderModel(encoder, decoder, data_handler)
encoder.summary(line_length=120)
print()
decoder.summary(line_length=125)
# Out:
# Model: "Encoder"
# ________________________________________________________________________________________________________________________
#  Layer (type)                          Output Shape               Param #       Connected to
# ========================================================================================================================
#  image (InputLayer)                    [(None, 432, 48, 3)]       0             []
#
#  block1_conv1 (Conv2D)                 (None, 432, 48, 64)        1792          ['image[0][0]']
#
#  block1_bn1 (BatchNormalization)       (None, 432, 48, 64)        256           ['block1_conv1[0][0]']
#
#  block1_relu1 (Activation)             (None, 432, 48, 64)        0             ['block1_bn1[0][0]']
#
#  block1_pool (MaxPooling2D)            (None, 216, 24, 64)        0             ['block1_relu1[0][0]']
#
#  block2_conv1 (Conv2D)                 (None, 216, 24, 128)       73856         ['block1_pool[0][0]']
#
#  block2_bn1 (BatchNormalization)       (None, 216, 24, 128)       512           ['block2_conv1[0][0]']
#
#  block2_relu1 (Activation)             (None, 216, 24, 128)       0             ['block2_bn1[0][0]']
#
#  block2_pool (MaxPooling2D)            (None, 108, 12, 128)       0             ['block2_relu1[0][0]']
#
#  block3_conv1 (Conv2D)                 (None, 108, 12, 256)       295168        ['block2_pool[0][0]']
#
#  block3_bn1 (BatchNormalization)       (None, 108, 12, 256)       1024          ['block3_conv1[0][0]']
#
#  block3_relu1 (Activation)             (None, 108, 12, 256)       0             ['block3_bn1[0][0]']
#
#  block3_conv2 (Conv2D)                 (None, 108, 12, 256)       590080        ['block3_relu1[0][0]']
#
#  block3_bn2 (BatchNormalization)       (None, 108, 12, 256)       1024          ['block3_conv2[0][0]']
#
#  block3_relu2 (Activation)             (None, 108, 12, 256)       0             ['block3_bn2[0][0]']
#
#  block3_pool (MaxPooling2D)            (None, 54, 6, 256)         0             ['block3_relu2[0][0]']
#
#  block4_conv1 (Conv2D)                 (None, 54, 6, 512)         1180160       ['block3_pool[0][0]']
#
#  block4_bn1 (BatchNormalization)       (None, 54, 6, 512)         2048          ['block4_conv1[0][0]']
#
#  block4_relu1 (Activation)             (None, 54, 6, 512)         0             ['block4_bn1[0][0]']
#
#  block4_conv2 (Conv2D)                 (None, 54, 6, 512)         2359808       ['block4_relu1[0][0]']
#
#  block4_bn2 (BatchNormalization)       (None, 54, 6, 512)         2048          ['block4_conv2[0][0]']
#
#  block4_relu2 (Activation)             (None, 54, 6, 512)         0             ['block4_bn2[0][0]']
#
#  block4_pool (MaxPooling2D)            (None, 27, 3, 512)         0             ['block4_relu2[0][0]']
#
#  block5_conv1 (Conv2D)                 (None, 26, 2, 512)         1049088       ['block4_pool[0][0]']
#
#  block5_bn1 (BatchNormalization)       (None, 26, 2, 512)         2048          ['block5_conv1[0][0]']
#
#  block5_relu1 (Activation)             (None, 26, 2, 512)         0             ['block5_bn1[0][0]']
#
#  block5_conv2 (Conv2D)                 (None, 25, 1, 512)         1049088       ['block5_relu1[0][0]']
#
#  block5_bn2 (BatchNormalization)       (None, 25, 1, 512)         2048          ['block5_conv2[0][0]']
#
#  block5_relu2 (Activation)             (None, 25, 1, 512)         0             ['block5_bn2[0][0]']
#
#  rnn_input (Reshape)                   (None, 25, 512)            0             ['block5_relu2[0][0]']
#
#  bigru1 (Bidirectional)                (None, 25, 512)            1182720       ['rnn_input[0][0]']
#
#  bigru2 (Bidirectional)                [(None, 25, 512),          1182720       ['bigru1[0][0]']
#                                         (None, 256),
#                                         (None, 256)]
#
#  skip_connection (Concatenate)         (None, 25, 1024)           0             ['rnn_input[0][0]',
#                                                                                  'bigru2[0][0]']
#
#  encoder_state (Concatenate)           (None, 512)                0             ['bigru2[0][1]',
#                                                                                  'bigru2[0][2]']
#
# ========================================================================================================================
# Total params: 8,975,488
# Trainable params: 8,969,984
# Non-trainable params: 5,504
# ________________________________________________________________________________________________________________________
#
# Model: "Decoder"
# _____________________________________________________________________________________________________________________________
#  Layer (type)                            Output Shape               Param #        Connected to
# =============================================================================================================================
#  encoder_sequence (InputLayer)           [(None, 25, 1024)]         0              []
#
#  previous_state (InputLayer)             [(None, 512)]              0              []
#
#  BahdanauAttention (BahdanauAttention)   ((None, 1024),             787969         ['encoder_sequence[0][0]',
#                                           (None, 25, 1))                            'previous_state[0][0]']
#
#  new_token (InputLayer)                  [(None, 1)]                0              []
#
#  tf.expand_dims (TFOpLambda)             (None, 1, 1024)            0              ['BahdanauAttention[0][0]']
#
#  embedding (Embedding)                   (None, 1, 512)             3831296        ['new_token[0][0]']
#
#  context_and_embedding (Concatenate)     (None, 1, 1536)            0              ['tf.expand_dims[0][0]',
#                                                                                     'embedding[0][0]']
#
#  dec_gru (GRU)                           [(None, 1, 512),           3148800        ['context_and_embedding[0][0]',
#                                           (None, 512)]                              'previous_state[0][0]']
#
#  flatten (Flatten)                       (None, 512)                0              ['dec_gru[0][0]']
#
#  prediction (Dense)                      (None, 7483)               3838779        ['flatten[0][0]']
#
# =============================================================================================================================
# Total params: 11,606,844
# Trainable params: 11,606,844
# Non-trainable params: 0
# _____________________________________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
train_idxs = list(range(dataset.size - NUM_VALIDATE))
valid_idxs = list(range(train_idxs[-1] + 1, dataset.size))
print('Number of training samples:', len(train_idxs))
print('Number of validate samples:', len(valid_idxs))
# Out:
# Number of training samples: 30259
# Number of validate samples: 7577

# %%
import random
random.seed(2022)
random.shuffle(train_idxs)

# When run on a small RAM machine, you can set use_cache=False to 
# not run out of memory but it will slow down the training speed
train_tf_dataset = data_handler.prepare_tf_dataset(train_idxs, BATCH_SIZE, drop_remainder=True)
valid_tf_dataset = data_handler.prepare_tf_dataset(valid_idxs, BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# ## Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping_callback = EarlyStopping(
    monitor = 'val_loss', 
    min_delta = 1e-3, # Change that less than 1e-3, will count as no improvement
    patience = 5, # Stop if no improvement after 5 epochs
    restore_best_weights = True, # Restore weights from the epoch with the best value
    verbose = 1
)

# Reduce the learning rate once learning stagnates
reduce_lr_callback = ReduceLROnPlateau(
    monitor = 'val_loss', 
    patience = 2, # Reduce if no improvement after 2 epochs
    min_lr = 1e-6, # Lower bound on the learning rate 
    factor = 0.5, # => new_lr = lr * factor
    verbose = 1
)

# %% [markdown]
# ## Fine-tuning the NomNaOCR dataset

# %%
from losses import MaskedLoss
from metrics import SequenceAccuracy, CharacterAccuracy, LevenshteinDistance
from tensorflow.keras.optimizers import Adam
LEARNING_RATE = 2e-4
EPOCHS = 100

# %%
model.compile(
    optimizer = Adam(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [
        SequenceAccuracy(),
        CharacterAccuracy(),
        LevenshteinDistance(normalize=True, name='lev_distance')
    ]
)

# %%
# %%time
history = model.fit(
    train_tf_dataset,
    validation_data = valid_tf_dataset,
    epochs = EPOCHS,
    callbacks = [reduce_lr_callback, early_stopping_callback],
    verbose = 1
).history
# Out:
# Epoch 1/100
# 945/945 [==============================] - 235s 216ms/step - loss: 4.8041 - seq_acc: 1.3228e-04 - char_acc: 0.1001 - lev_distance: 0.8004 - val_loss: 1.4535 - val_seq_acc: 7.9449e-04 - val_char_acc: 0.1423 - val_lev_distance: 0.7466 - lr: 2.0000e-04
# Epoch 2/100
# 945/945 [==============================] - 190s 201ms/step - loss: 3.9756 - seq_acc: 0.0077 - char_acc: 0.2138 - lev_distance: 0.6855 - val_loss: 1.3231 - val_seq_acc: 0.0094 - val_char_acc: 0.1601 - val_lev_distance: 0.7095 - lr: 2.0000e-04
# Epoch 3/100
# 945/945 [==============================] - 190s 201ms/step - loss: 3.2663 - seq_acc: 0.0215 - char_acc: 0.3207 - lev_distance: 0.5807 - val_loss: 1.1489 - val_seq_acc: 0.0314 - val_char_acc: 0.3966 - val_lev_distance: 0.5225 - lr: 2.0000e-04
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 945/945 [==============================] - 190s 201ms/step - loss: 0.3626 - seq_acc: 0.4411 - char_acc: 0.9133 - lev_distance: 0.0788 - val_loss: 0.5756 - val_seq_acc: 0.1984 - val_char_acc: 0.8304 - val_lev_distance: 0.1617 - lr: 1.2500e-05
# Epoch 45/100
# 945/945 [==============================] - ETA: 0s - loss: 0.3557 - seq_acc: 0.4495 - char_acc: 0.9156 - lev_distance: 0.0768Restoring model weights from the end of the best epoch: 40.
# 945/945 [==============================] - 190s 201ms/step - loss: 0.3558 - seq_acc: 0.4495 - char_acc: 0.9156 - lev_distance: 0.0768 - val_loss: 0.5732 - val_seq_acc: 0.2015 - val_char_acc: 0.8313 - val_lev_distance: 0.1611 - lr: 6.2500e-06
# Epoch 45: early stopping
# CPU times: total: 3h 39min 54s
# Wall time: 2h 23min 20s

# %% [markdown]
# ## Save the training results

# %%
best_epoch = early_stopping_callback.best_epoch
print(f'- Loss on validation\t: {history["val_loss"][best_epoch]}')
print(f'- Sequence accuracy\t: {history["val_seq_acc"][best_epoch]}')
print(f'- Character accuracy\t: {history["val_char_acc"][best_epoch]}')
print(f'- Levenshtein distance\t: {history["val_lev_distance"][best_epoch]}')
# Out:
# - Loss on validation	: 0.5716767311096191
# - Sequence accuracy	: 0.1837923675775528
# - Character accuracy	: 0.8176007866859436
# - Levenshtein distance	: 0.1728724241256714

# %%
from visualizer import plot_training_results
plot_training_results(history, f'finetune_{APPROACH_NAME}.png')
model.encoder.save_weights(f'finetune_{APPROACH_NAME}_enc.h5')
model.decoder.save_weights(f'finetune_{APPROACH_NAME}_dec.h5')

# %% [markdown]
# # Inference

# %%
encoder = Encoder(imagenet_model, imagenet_output_layer)
decoder = Decoder(encoder.outputs[0].shape[1:])
encoder.load_weights(f'Fine-tuning/finetune_{APPROACH_NAME}_enc.h5')
decoder.load_weights(f'Fine-tuning/finetune_{APPROACH_NAME}_dec.h5')

# %%
reset_model = EncoderDecoderModel(encoder, decoder, data_handler)
reset_model.compile(
    optimizer = Adam(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [
        SequenceAccuracy(),
        CharacterAccuracy(),
        LevenshteinDistance(normalize=True, name='lev_distance')
    ]
)

# %% [markdown]
# ## On test dataset

# %%
batch_results = []
for idx, (batch_images, batch_tokens) in enumerate(valid_tf_dataset.take(1)):
    idxs_in_batch = valid_idxs[idx * BATCH_SIZE: (idx + 1) * BATCH_SIZE]
    labels = data_handler.tokens2texts(batch_tokens)
    pred_tokens, attentions = reset_model.predict(batch_images, return_attention=True)
    pred_labels = data_handler.tokens2texts(pred_tokens)
    
    batch_results.append({'true': labels, 'pred': pred_labels, 'attentions': attentions})
    visualize_images_labels(
        img_paths = dataset.img_paths[idxs_in_batch], 
�曰人謀之不熾是亦天運之有救史', 16: '之以本月十九日還塟于御天之盡舍鄕二十', 17: '群恩副之卒定三年一貢爲常例二月二十四', 18: '京恐爲不便帝從之故有是命令陳人著京', 19: '鄕人也以太祖起義六年癸卯冬十一月二', 20: '献六眸益督中有衛文二行群臣辨之成王以公', 21: '為既朝且絶民之望李氏也秋七月二十二日', 22: '季犛二十員人入鳳\U000f0029堂帝自命題試之九日', 23: '府每以日燏子孫爲之如國康之於演州是也', 24: '國之乃拜二人為鎮威副将軍令五府軍以陣圖', 25: '進上皇嘉之賜田四十𤱈以為後日脩行之資起', 26: '二十七日旨揮置社官大社一百人以上用二', 27: '精氣因結爲此故也世人以不常見而異之外', 28: '王還年間木印帖子者國定官以為僞上皇聞之', 29: '天子之地至是帝以甲戌年生為天子乘', 30: '夏四月旱二十三日祈于是天上帝以自冬送', 31: '之曰何日擒\U000f0c50䦕内人其事始和帝知意不解', 32: '甚長非我國之灾復命參宴是年冬十月宋帝節'}

# %% [markdown]
# ## On random image

# %%
random_path = '../囷𦝄苔惮󰞺𧍋𦬑囊.jpg'
random_label = '囷𦝄苔惮󰞺𧍋𦬑囊'
random_image = data_handler.process_image(random_path)
pred_tokens = reset_model.predict(tf.expand_dims(random_image, axis=0))
pred_labels = data_handler.tokens2texts(pred_tokens)

# %%
visualize_images_labels(
    img_paths = [random_path], 
    labels = [random_label], 
    pred_labels = pred_labels,
    figsize = (5, 4),
    subplot_size = (1, 1), 
    font_path = FONT_PATH, 
)
print('Predicted text:', ''.join(pred_labels))
# Out:
# Predicted text: 厨𦝄意惮󰞺𣈜安襲

# %% [markdown]
# # Detail evaluation

# %%
import pandas as pd
from evaluator import Evaluator
GT10_TRANSCRIPTS_PATH = f'{DATASET_DIR}/Validate_gt10.txt'
LTE10_TRANSCRIPTS_PATH = f'{DATASET_DIR}/Validate_lte10.txt'

# %%
gt10_evaluator = Evaluator(reset_model, DATASET_DIR, GT10_TRANSCRIPTS_PATH)
lte10_evaluator = Evaluator(reset_model, DATASET_DIR, LTE10_TRANSCRIPTS_PATH)
df = pd.DataFrame([
    reset_model.evaluate(valid_tf_dataset, return_dict=True),
    gt10_evaluator.evaluate(data_handler, BATCH_SIZE, drop_remainder=True),
    lte10_evaluator.evaluate(data_handler, BATCH_SIZE, drop_remainder=True),
])
df.index = ['Full', 'Length > 10', 'Length ≤ 10']
df
# Out:
# 236/236 [==============================] - 40s 98ms/step - loss: 0.7252 - seq_acc: 0.1838 - char_acc: 0.8176 - lev_distance: 0.1729
# 120/120 [==============================] - 12s 100ms/step - loss: 0.8379 - seq_acc: 0.0617 - char_acc: 0.8178 - lev_distance: 0.1727
# 116/116 [==============================] - 11s 97ms/step - loss: 0.4172 - seq_acc: 0.3106 - char_acc: 0.8184 - lev_distance: 0.1731
#                  loss   seq_acc  char_acc  lev_distance
# Full         0.571677  0.183792  0.817601      0.172872
# Length > 10  1.309249  0.061719  0.817774      0.172731
# Length ≤ 10  0.620706  0.310614  0.818428      0.173075
